# %% [markdown]
# <a href="https://colab.research.google.com/github/Athira-codes/ml-projects/blob/main/car_resale(traindata)_regression0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/DATASETS/train-data.csv')
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df.drop(['Unnamed: 0','New_Price'],axis=1,inplace=True)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df.isna().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
df['Mileage']=df['Mileage'].str.replace('kmpl','')
df['Mileage']=df['Mileage'].str.replace('km/kg','')
df['Engine']=df['Engine'].str.replace('CC','')
df['Power']=df['Power'].str.replace('bhp','')
df['Power']=df['Power'].str.replace('null','0')
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
df.loc[df['Power']=='null '][['Power']]
# Out:
# Empty DataFrame
# Columns: [Power]
# Index: []

# %%
#astype
df['Mileage']=df['Mileage'].astype(float)
df['Engine']=df['Engine'].astype(float)
df['Power']=df['Power'].astype(float)

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %%
import numpy as np
df.loc[df.Power==0,'Power']=np.NaN

# %%
lst1=['Engine','Seats']
for i in lst1:
  df[i]=df[i].fillna(df[i].mode()[0])
lst2=['Mileage','Power']
for i in lst2:
  df[i]=df[i].fillna(df[i].mean())

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df.isna().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.dtypes
# objects are present
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %%
# label encoder(class)
# map()

# %%
df['Owner_Type'].unique()
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
# map
# df['Owner_Type']=df['Owner_Type'].map({'First':0,'Second':1,'Third':2,'Fourth & Above':3})
# df['Transmission']=df['Transmission'].map({'Manual':0,'Automatic':1})
# df

# %%
# splitting Name column
df['brand']=df['Name'].apply(lambda x:x.split()[0])

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df.drop(['Name'],axis=1,inplace=True)
df
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
#       Mileage  Engine   Power  Seats  Price      brand
# ...

# %%
df['brand'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Smart', 'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley',
#        'Lamborghini'], dtype=object)

# %%
# label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Owner_Type']=le.fit_transform(df['Owner_Type'])
le1=LabelEncoder()
df['brand']=le1.fit_transform(df['brand'])
le2=LabelEncoder()
df['Transmission']=le2.fit_transform(df['Transmission'])
le3=LabelEncoder()
df['Fuel_Type']=le3.fit_transform(df['Fuel_Type'])
le4=LabelEncoder()
df['Location']=le4.fit_transform(df['Location'])
df
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0            9  2010              72000          0             1           0
# 1           10  2015              41000          1             1           0
# 2            2  2011              46000          4             1           0
# 3            2  2012              87000          1             1           0
# 4            3  2013              40670          1             0           2
# ...        ...   ...                ...        ...           ...         ...
# 6014         4  2014              27365          1             1           0
# 6015         6  2015             100000          1             1           0
# 6016         6  2012              55000          1             1           2
# 6017         8  2013              46000          4             1           0
# 6018         5  2011              47000          1             1           0
#
# ...

# %%
# to bring the values 0 and 1 as original terms in owner type
# df['Owner_Type']=le.inverse_transform(df['Owner_Type'])
# df

# %%
le.classes_
# Out:
# array(['First', 'Fourth & Above', 'Second', 'Third'], dtype=object)

# %%
le.transform(le.classes_)
# Out:
# array([0, 1, 2, 3])

# %%
mapping=list(zip(le.classes_,le.transform(le.classes_)))
mapping
# Out:
# [('First', 0), ('Fourth & Above', 1), ('Second', 2), ('Third', 3)]

# %%
mapping=list(zip(le1.classes_,le1.transform(le1.classes_)))
mapping
# Out:
# [('Ambassador', 0),
#  ('Audi', 1),
#  ('BMW', 2),
#  ('Bentley', 3),
#  ('Chevrolet', 4),
#  ('Datsun', 5),
#  ('Fiat', 6),
#  ('Force', 7),
#  ('Ford', 8),
#  ('Honda', 9),
#  ('Hyundai', 10),
#  ('ISUZU', 11),
#  ('Isuzu', 12),
#  ('Jaguar', 13),
#  ('Jeep', 14),
#  ('Lamborghini', 15),
#  ('Land', 16),
#  ('Mahindra', 17),
#  ('Maruti', 18),
#  ('Mercedes-Benz', 19),
#  ('Mini', 20),
#  ('Mitsubishi', 21),
#  ('Nissan', 22),
#  ('Porsche', 23),
#  ('Renault', 24),
#  ('Skoda', 25),
#  ('Smart', 26),
#  ('Tata', 27),
#  ('Toyota', 28),
#  ('Volkswagen', 29),
#  ('Volvo', 30)]

# %%
mapping=list(zip(le2.classes_,le2.transform(le2.classes_)))
mapping
# Out:
# [('Automatic', 0), ('Manual', 1)]

# %%
mapping=list(zip(le3.classes_,le3.transform(le3.classes_)))
mapping
# Out:
# [('CNG', 0), ('Diesel', 1), ('Electric', 2), ('LPG', 3), ('Petrol', 4)]

# %%
mapping=list(zip(le4.classes_,le4.transform(le4.classes_)))
mapping
# Out:
# [('Ahmedabad', 0),
#  ('Bangalore', 1),
#  ('Chennai', 2),
#  ('Coimbatore', 3),
#  ('Delhi', 4),
#  ('Hyderabad', 5),
#  ('Jaipur', 6),
#  ('Kochi', 7),
#  ('Kolkata', 8),
#  ('Mumbai', 9),
#  ('Pune', 10)]

# %%
df
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0            9  2010              72000          0             1           0
# 1           10  2015              41000          1             1           0
# 2            2  2011              46000          4             1           0
# 3            2  2012              87000          1             1           0
# 4            3  2013              40670          1             0           2
# ...        ...   ...                ...        ...           ...         ...
# 6014         4  2014              27365          1             1           0
# 6015         6  2015             100000          1             1           0
# 6016         6  2012              55000          1             1           2
# 6017         8  2013              46000          4             1           0
# 6018         5  2011              47000          1             1           0
#
# ...

# %%
df.dtypes
# Out:
# Location               int64
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int64
# Transmission           int64
# Owner_Type             int64
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# brand                  int64
# dtype: object

# %%
X=df.drop(['Price'],axis=1)
X
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0            9  2010              72000          0             1           0
# 1           10  2015              41000          1             1           0
# 2            2  2011              46000          4             1           0
# 3            2  2012              87000          1             1           0
# 4            3  2013              40670          1             0           2
# ...        ...   ...                ...        ...           ...         ...
# 6014         4  2014              27365          1             1           0
# 6015         6  2015             100000          1             1           0
# 6016         6  2012              55000          1             1           2
# 6017         8  2013              46000          4             1           0
# 6018         5  2011              47000          1             1           0
#
#       Mileage  Engine   Power  Seats  brand
# ...

# %%
y=df.iloc[:,-2]
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 6019, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
X=mms.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train.shape,y_train.shape
# Out:
# ((4213, 11), (4213,))

# %%
X_test.shape,y_test.shape
# Out:
# ((1806, 11), (1806,))

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mlr.predict(X_test)
y_pred
# Out:
# array([38.5635746 ,  2.14166629, 11.39743292, ...,  2.36846944,
#         3.80652284,  2.51023688])

# %%
y_test
# Out:
# 2319    78.80
# 3652     3.51
# 2397     6.00
# 3536    10.28
# 4400     2.35
#         ...
# 4865     5.77
# 3194    24.77
# 1253     2.00
# 1041     4.57
# 1697     3.25
# Name: Price, Length: 1806, dtype: float64

# %%
print("coefficient:",mlr.coef_)
print("intercept:",mlr.intercept_)
# Out:
# coefficient: [-2.11021598e+00  1.89341200e+01 -1.55093853e+02 -3.61702113e+00
#  -2.44578283e+00 -1.16567258e-01 -6.17452237e+00  5.31796269e+00
#   6.48563006e+01 -9.04587763e+00 -1.35082212e-01]
# intercept: -0.9140776024324069

# %%
import numpy as np

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print("r2_score=",r2_score(y_test,y_pred))
print("MAE=",mean_absolute_error(y_test,y_pred))
print("MSE=",mean_squared_error(y_test,y_pred))
print("RMSE=",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score= 0.5884228894902455
# MAE= 3.6340948512743423
# MSE= 48.87654916494532
# RMSE= 6.991176522227523

# %%
# scaler
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn=knn.predict(X_test)
y_pred_knn
# Out:
# array([55.592,  2.11 ,  5.49 , ...,  3.916,  4.044,  3.34 ])

# %%
from sklearn.metrics  import r2_score,mean_absolute_error,mean_squared_error
print("r2_score=",r2_score(y_test,y_pred_knn))
print("MAE=",mean_absolute_error(y_test,y_pred_knn))
print("MSE=",mean_squared_error(y_test,y_pred_knn))
# Out:
# r2_score= 0.8487708333687148
# MAE= 2.15018161683278
# MSE= 17.959112908084162

# %%
y_new=knn.predict([[9,2010,72000,0,1,0,26.60,998.0,58.16,5.0,18]])
y_new.item()
# Out:
# 5.2299999999999995
